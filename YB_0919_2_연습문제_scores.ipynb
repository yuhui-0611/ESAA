# %% [markdown]
# <a href="https://colab.research.google.com/github/yuhui-0611/ESAA/blob/main/YB_0919_2_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_scores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scores

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
# ***Exercise based on [Chris Albon](http://chrisalbon.com/) work, the credits belong to him.***
#
# ### Step 1. Import the necessary libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Create the DataFrame that should look like the one below.
# *참고*
#
# ```
# raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#             'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#             'female': [0, 1, 1, 0, 1],
#             'age': [42, 52, 36, 24, 73],
#             'preTestScore': [4, 24, 31, 2, 3],
#             'postTestScore': [25, 94, 57, 62, 70]}
# ```

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
            'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
            'female': [0, 1, 1, 0, 1],
            'age': [42, 52, 36, 24, 73],
            'preTestScore': [4, 24, 31, 2, 3],
            'postTestScore': [25, 94, 57, 62, 70]}
test = pd.DataFrame(raw_data)

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
plt.scatter(x=test['preTestScore'], y=test['postTestScore'], s=test['age'], c = "pink")
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('preTestScore & postTestScore')
plt.show()

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
plt.scatter(x=test['preTestScore'], y=test['postTestScore'], s=test['postTestScore']*4.5, c = test['female'])
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.title('preTestScore & postTestScore - sex')
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
test['improveScore'] = test['postTestScore'] - test['preTestScore']
test
# Out:
#   first_name last_name  female  age  preTestScore  postTestScore  improveScore
# 0      Jason    Miller       0   42             4             25            21
# 1      Molly  Jacobson       1   52            24             94            70
# 2       Tina       Ali       1   36            31             57            26
# 3       Jake    Milner       0   24             2             62            60
# 4        Amy     Cooze       1   73             3             70            67

# %%
plt.bar(x=test['first_name'], height=test['improveScore'], color='pink')
plt.ylabel('Improvement')
plt.title('Score Improvement by Student')
plt.show()
